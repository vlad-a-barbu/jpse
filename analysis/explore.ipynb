# %%
import pandas as pd

# %%
df = pd.read_csv('./data/linkedin_business-analyst_results.csv')
df.head(30)
# Out:
#                        EntityUrn                  SearchId
# 0   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==  \
# 1   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 2   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 3   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 4   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 5   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 6   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 7   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 8   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 9   urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 10  urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 11  urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 12  urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 13  urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# 14  urn:li:jobPosting:3609480937  a0EQwbOkXqSdDGHf+lBV1g==
# ...
